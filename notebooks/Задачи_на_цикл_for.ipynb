# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnSenina/Python_CL_2023/blob/main/notebooks/%D0%97%D0%B0%D0%B4%D0%B0%D1%87%D0%B8_%D0%BD%D0%B0_%D1%86%D0%B8%D0%BA%D0%BB_for.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Задача 1

# %% [markdown]
# Топ-5 книг, которые точно пригодятся цифровому гуманитарию из тг-канала ***Гуманитарии в цифре***

# %% [markdown]
# Хрестоматия «Цифровые гуманитарные науки» (http://lib3.sfu-kras.ru/ft/LIB2/ELIB/b71/free/i-531505996.pdf). В хрестоматии можно вычитать, как «цифровые гуманитарные науки» появились, самоопределелись и начали развиваться, познакомиться с разными определениями направления, узнать о типологии определений цифровых гуманитарных наук.
#
# Леонид Бородкин. «Моделирование исторических процессов: от реконструкции реальности к анализу альтернатив» (http://hist.msu.ru/research/publications/detail.php?ELEMENT_ID=53051). Леонид Иосифович объясняет, как смоделировать явления прошлого, используя современные математические методы и информационные технологии. Это первое комплексное исследование возможностей и ограничений моделирования исторических процессов: от математических моделей до виртуальных реконструкций.
#
# Борис Ярхо. «Методология точного литературоведения» (https://www.academia.edu/12497268/). Борис Исаакович сумел обобщенно представить возможности и ограничения количественной методологии в литературоведении, включив её в широкий контекст осмысления жизни человека и показав красоту и силу русского формализма.
#
# Лев Манович. «Язык новых медиа». (https://monster-book.com/yazyk-novyh-media) Лев Захарович, рассуждая о технологиях и режимах существования медиа, выстраивает генеалогию элементов информационной среды, демонстрируя анатомию новых — цифровых — медиа; создает в книге основу для нетривиальных, но доказуемых подходов к интерпретации артефактов современной культуры, стратегий и практик коммуникации для новой оптики изучения социальных, экономических и политических логик современности.
#
# Монография «Цифровые гуманитарные исследования» (http://lib3.sfu-kras.ru/ft/LIB2/ELIB/b71/free/i-494468.pdf?Z21ID=001063DC105A728B0C1063481092704B&P21DBN=BOOK1&Z21MFN=%D0%91%D0%91%D0%9A71%2F%D0%A6%20752-494468). В книге впервые на русском языке комплексно рассматривается направление Digital Humanities. Перед вами – широкая палитра цифровых подходов для поиска решений насущных гуманитарных исследовательских задач: от базы данных к сетевому анализу, от геоинформационных систем к виртуальным реконструкциям и дополненной реальности

# %%
titles = ['Цифровые гуманитарные науки (хрестоматия)',
          'Моделирование исторических процессов: от реконструкции реальности к анализу альтернатив',
          'Методология точного литературоведения',
          'Язык новых медиа',
          'Цифровые гуманитарные исследования (монография)']

titles_new = []

# 1: убедитесь, что все книги из списка titles добавятся в titles_new (любым способом)
# 2: внутри цикла for используйте input, чтобы запросить у пользователя ввод
#    и добавить еще 3 любые книги в список

# %%
# ваше решение ниже

# %% [markdown]
# # Задача 2

# %%
titles = ['Цифровые гуманитарные науки (хрестоматия)',
          'Моделирование исторических процессов: от реконструкции реальности к анализу альтернатив',
          'Методология точного литературоведения',
          'Язык новых медиа',
          'Цифровые гуманитарные исследования (монография)']

urls = ['http://lib3.sfu-kras.ru/ft/LIB2/ELIB/b71/free/i-531505996.pdf',
        'http://hist.msu.ru/research/publications/detail.php?ELEMENT_ID=53051',
        'https://www.academia.edu/12497268/',
        'https://monster-book.com/yazyk-novyh-media',
        'http://lib3.sfu-kras.ru/ft/LIB2/ELIB/b71/free/i-494468.pdf?Z21ID=001063DC105A728B0C1063481092704B&P21DBN=BOOK1&Z21MFN=%D0%91%D0%91%D0%9A71%2F%D0%A6%20752-494468']

annot = ['В хрестоматии можно вычитать, как «цифровые гуманитарные науки» появились, самоопределелись и начали развиваться, познакомиться с разными определениями направления, узнать о типологии определений цифровых гуманитарных наук',
         'Леонид Иосифович объясняет, как смоделировать явления прошлого, используя современные математические методы и информационные технологии. Это первое комплексное исследование возможностей и ограничений моделирования исторических процессов: от математических моделей до виртуальных реконструкций.',
         'Борис Исаакович сумел обобщенно представить возможности и ограничения количественной методологии в литературоведении, включив её в широкий контекст осмысления жизни человека и показав красоту и силу русского формализма',
         'Лев Захарович, рассуждая о технологиях и режимах существования медиа, выстраивает генеалогию элементов информационной среды, демонстрируя анатомию новых — цифровых — медиа; создает в книге основу для нетривиальных, но доказуемых подходов к интерпретации артефактов современной культуры, стратегий и практик коммуникации для новой оптики изучения социальных, экономических и политических логик современности.',
         'В книге впервые на русском языке комплексно рассматривается направление Digital Humanities. Перед вами – широкая палитра цифровых подходов для поиска решений насущных гуманитарных исследовательских задач: от базы данных к сетевому анализу, от геоинформационных систем к виртуальным реконструкциям и дополненной реальности.']

# %%
# У вас есть 3 разных списка одинаковой длины.
# Напечатайте информацию обо всех книгах в формате:

# Книга: название
# Аннотация: текст аннотации
# Почитать можно здесь: ссылка

# Пример ответа:

# Книга: Цифровые гуманитарные науки (хрестоматия)
# Аннотация: В хрестоматии можно вычитать, как «цифровые гуманитарные науки» появились, самоопределелись и начали развиваться, познакомиться с разными определениями направления, узнать о типологии определений цифровых гуманитарных наук
# Почитать можно здесь: http://lib3.sfu-kras.ru/ft/LIB2/ELIB/b71/free/i-531505996.pdf
#
# Книга2...

# %%
# ваше решение ниже

# %% [markdown]
# # Задание 3

# %% [markdown]
# Продолжаем работать с теми же книгами.
#
# К исходным спискам добавился новый:

# %%
tags = ['theory', 'history', 'text', 'text', 'theory']

# %%
# Вы хотите запрашивать у человека tag книги, а затем печатать информацию только о тех книгах, у которых соответствующий tag

tag = input() # например, 'theory'

# напишите решение с if - else, чтобы по заданному тегу печатались книги в формате:

# Вот все книги с выбранным тегом по вашему запросу:
# Книга: Цифровые гуманитарные науки (хрестоматия).
# Аннотация: В хрестоматии можно вычитать, как «цифровые гуманитарные науки» появились, самоопределелись и начали развиваться, познакомиться с разными определениями направления, узнать о типологии определений цифровых гуманитарных наук
# Почитать можно здесь: http://lib3.sfu-kras.ru/ft/LIB2/ELIB/b71/free/i-531505996.pdf
# Книга...

# %% [markdown]
# ### Забегая вперед к методам...
#
# Посмоторите на данные:

# %%
f1 = '''"file_id","genus","species","english_cname","who_provided_recording","country","latitude","longitute","type","license"
132608,"Acanthis","flammea","Common Redpoll","Jarek Matusiak","Poland",50.7932,15.4995,"female, male, song","http://creativecommons.org/licenses/by-nc-sa/3.0/"
132611,"Acanthis","flammea","Common Redpoll","Jarek Matusiak","Poland",50.7932,15.4995,"flight call, male, song","http://creativecommons.org/licenses/by-nc-sa/3.0/"
35068,"Acanthis","flammea","Common Redpoll","Sander Bot","Netherlands",52.8176,6.4326,"call, song","http://creativecommons.org/licenses/by-nc-nd/2.5/"'''

f2 = '''Countries of the UK,PCON14NM,house,salary,publicsector,degree,age,nonukborn,health
Wales,Rhondda,62000,432.4,38.9,14,33,2.1,70.6
England,Clacton,150000,426.4,26.1,13.4,39,4.3,70.9
England,Easington,80000,438.7,20.2,15.3,41,2.2,71.8
Wales,Merthyr Tydfil and Rhymn,82000,434,35.1,16.4,46,3.9,72.1'''

# Можно ли их превратить в список списков:
# [ [], [], ... ] ?
