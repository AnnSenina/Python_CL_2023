# %%
import tkinter as tk
symbol_dict = {
    "!" : "восклицательный знак",
    "@" : "собака",
    "#" : "решетка",
    "$" : "доллар",
    "€" : "евро",
    "¥" : "юань",
    "£" : "фунт",
    "¤" : "занк валюты",
    "฿" : "бат",
    "%" : "знак процента",
    "^" : "знак крышки",
    "&" : "амперсанд",
    "*" : "звездочка",
    "(" : "открывающая скобка",
    ")" : "закрывающая скобка",
    "♡" : "сердечко",
    "ღ" : "сердечко",
    "❥" : "сердечко",
    "❤" : "сердечко",
    "♥" : "сердечко",
    "❣" : "сердечко",
    "❦" : "сердечко",
    "❧" : "сердечко",
    "⓵" : "цифра в кружочке",
    "⓶" : "цифра в кружочке",
    "⓷" : "цифра в кружочке",
    "⓸" : "цифра в кружочке",
    "⓹" : "цифра в кружочке",
    "⓺" : "цифра в кружочке",
    "⓻" : "цифра в кружочке",
    "⓼" : "цифра в кружочке",
    "⓽" : "цифра в кружочке",
    "⓾" : "цифра в кружочке",
    "➊" : "цифра в кружочке",
    "➋" : "цифра в кружочке",
    "➌" : "цифра в кружочке",
    "➍" : "цифра в кружочке",
    "➎" : "цифра в кружочке",
    "➏" : "цифра в кружочке",
    "➐" : "цифра в кружочке",
    "➑" : "цифра в кружочке",
    "➒" : "цифра в кружочке",
    "➓" : "цифра в кружочке",
    "⓪" : "цифра в кружочке",
    "➀" : "цифра в кружочке",
    "➁" : "цифра в кружочке",
    "➂" : "цифра в кружочке",
    "➃" : "цифра в кружочке",
    "➄" : "цифра в кружочке",
    "➅" : "цифра в кружочке",
    "➆" : "цифра в кружочке",
    "➇" : "цифра в кружочке",
    "➈" : "цифра в кружочке",
    "➉" : "цифра в кружочке",
    "⑪" : "цифра в кружочке",
    "⑫" : "цифра в кружочке",
    "⑬" : "цифра в кружочке",
    "⑭" : "цифра в кружочке",
    "⑮" : "цифра в кружочке",
    "⑯" : "цифра в кружочке",
    "⑰" : "цифра в кружочке",
    "⑱" : "цифра в кружочке",
    "⑲" : "цифра в кружочке",
    "⑳" : "цифра в кружочке",
    "❶" : "цифра в кружочке",
    "❷" : "цифра в кружочке",
    "❸" : "цифра в кружочке",
    "❹" : "цифра в кружочке",
    "❺" : "цифра в кружочке",
    "❻" : "цифра в кружочке",
    "❼" : "цифра в кружочке",
    "❽" : "цифра в кружочке",
    "❾" : "цифра в кружочке",
    "❿" : "цифра в кружочке",
    "Ⓐ" : "буквы в кружочках",
    "Ⓑ" : "буквы в кружочках",
    "Ⓒ" : "буквы в кружочках",
    "Ⓓ" : "буквы в кружочках",
    "Ⓔ" : "буквы в кружочках",
    "Ⓕ" : "буквы в кружочках",
    "Ⓖ" : "буквы в кружочках",
    "Ⓗ" : "буквы в кружочках",
    "Ⓘ" : "буквы в кружочках",
    "Ⓙ" : "буквы в кружочках",
    "Ⓚ" : "буквы в кружочках",
    "Ⓛ" : "буквы в кружочках",
    "Ⓜ" : "буквы в кружочках",
    "Ⓝ" : "буквы в кружочках",
    "Ⓞ" : "буквы в кружочках",
    "Ⓟ" : "буквы в кружочках",
    "Ⓠ" : "буквы в кружочках",
    "Ⓡ" : "буквы в кружочках",
    "Ⓢ" : "буквы в кружочках",
    "Ⓣ" : "буквы в кружочках",
    "Ⓤ" : "буквы в кружочках",
    "Ⓥ" : "буквы в кружочках",
    "Ⓦ" : "буквы в кружочках",
    "Ⓧ" : "буквы в кружочках",
    "Ⓨ" : "буквы в кружочках",
    "Ⓩ" : "буквы в кружочках",
    "∅" : "круг",
    "❂" : "круг",
    "○" : "круг",
    "◎" : "круг",
    "●" : "круг",
    "◯" : "круг",
    "⊙" : "круг",
    "⊗" : "круг",
    "◍" : "круг",
    "◉" : "круг",
    "⊕" : "плюс в кружочке",
    "⊖" : "минус в кружочке",
    "⊘" : "дробь в кружочке",
    "⊛" : "звездочка в кружочке",
    "⊜" : "равно в кружочке",
    "↪" : "стрелка",
    "↩" : "стрелка",
    "←" : "стрелка",
    "↑" : "стрелка",
    "→" : "стрелка",
    "↓" : "стрелка",
    "↔" : "стрелка",
    "↕" : "стрелка",
    "↖" : "стрелка",
    "↗" : "стрелка",
    "↘" : "стрелка",
    "↙" : "стрелка",
    "↚" : "стрелка",
    "↛" : "стрелка",
    "↜" : "стрелка",
    "↝" : "стрелка",
    "↞" : "стрелка",
    "↟" : "стрелка",
    "↠" : "стрелка",
    "↡" : "стрелка",
    "↢" : "стрелка",
    "↣" : "стрелка",
    "↤" : "стрелка",
    "↦" : "стрелка",
    "↥" : "стрелка",
    "↧" : "стрелка",
    "↨" : "стрелка",
    "↫" : "стрелка",
    "↬" : "стрелка",
    "↭" : "стрелка",
    "↮" : "стрелка",
    "↯" : "стрелка",
    "↰" : "стрелка",
    "↱" : "стрелка",
    "↲" : "стрелка",
    "↴" : "стрелка",
    "↳" : "стрелка",
    "↵" : "стрелка",
    "↶" : "стрелка",
    "↷" : "стрелка",
    "↸" : "стрелка",
    "↹" : "стрелка",
    "↺" : "стрелка",
    "↻" : "стрелка",
    "⟲" : "стрелка",
    "⟳" : "стрелка",
    "↼" : "стрелка",
    "↽" : "стрелка",
    "↾" : "стрелка",
    "↿" : "стрелка",
    "⇀" : "стрелка",
    "⇁" : "стрелка",
    "⇂" : "стрелка",
    "⇃" : "стрелка",
    "⇄" : "стрелка",
    "⇅" : "стрелка",
    "⇆" : "стрелка",
    "⇇" : "стрелка",
    "⇈" : "стрелка",
    "⇉" : "стрелка",
    "⇊" : "стрелка",
    "⇋" : "стрелка",
    "⇌" : "стрелка",
    "⇍" : "стрелка",
    "⇎" : "стрелка",
    "⇏" : "стрелка",
    "⇑" : "стрелка",
    "⇓" : "стрелка",
    "⇐" : "стрелка",
    "⇒" : "стрелка",
    "⇔" : "стрелка",
    "⇕" : "стрелка",
    "⇖" : "стрелка",
    "⇗" : "стрелка",
    "⇘" : "стрелка",
    "⇙" : "стрелка",
    "⇳" : "стрелка",
    "⇚" : "стрелка",
    "⇛" : "стрелка",
    "⇜" : "стрелка",
    "⇝" : "стрелка",
    "⇞" : "стрелка",
    "⇟" : "стрелка",
    "⇠" : "стрелка",
    "⇡" : "стрелка",
    "⇢" : "стрелка",
    "⇣" : "стрелка",
    "⇤" : "стрелка",
    "⇥" : "стрелка",
    "⇦" : "стрелка",
    "⇨" : "стрелка",
    "⇩" : "стрелка",
    "⇪" : "стрелка",
    "⇫" : "стрелка",
    "⇬" : "стрелка",
    "⇭" : "стрелка",
    "⇮" : "стрелка",
    "⇯" : "стрелка",
    "⇰" : "стрелка",
    "⇱" : "стрелка",
    "⇲" : "стрелка",
    "⇳" : "стрелка",
    "⥀" : "стрелка",
    "⥁" : "стрелка",
    "⥂" : "стрелка",
    "⥃" : "стрелка",
    "⥄" : "стрелка",
    "⥅" : "стрелка",
    "⥆" : "стрелка",
    "⥇" : "стрелка",
    "⥈" : "стрелка",
    "⥉" : "стрелка",
    "⥒" : "стрелка",
    "⥓" : "стрелка",
    "⥔" : "стрелка",
    "⥕" : "стрелка",
    "⥖" : "стрелка",
    "⥗" : "стрелка",
    "⥘" : "стрелка",
    "⥙" : "стрелка",
    "⥚" : "стрелка",
    "⥛" : "стрелка",
    "⥜" : "стрелка",
    "⥝" : "стрелка",
    "⥞" : "стрелка",
    "⥟" : "стрелка",
    "⥠" : "стрелка",
    "⥡" : "стрелка",
    "⥢" : "стрелка",
    "⥣" : "стрелка",
    "⥤" : "стрелка",
    "⥥" : "стрелка",
    "⥦" : "стрелка",
    "⥹" : "стрелка",
    "⥧" : "стрелка",
    "⥨" : "стрелка",
    "⥩" : "стрелка",
    "⥪" : "стрелка",
    "⥫" : "стрелка",
    "⥬" : "стрелка",
    "⥭" : "стрелка",
    "⥮" : "стрелка",
    "⥯" : "стрелка",
    "⥰" : "стрелка",
    "⥱" : "стрелка",
    "⥲" : "стрелка",
    "⥳" : "стрелка",
    "⥴" : "стрелка",
    "⥵" : "стрелка",
    "⥶" : "стрелка",
    "⥷" : "стрелка",
    "⥸" : "стрелка",
    "⥺" : "стрелка",
    "⥻" : "стрелка",
    "➔" : "стрелка",
    "➘" : "стрелка",
    "➙" : "стрелка",
    "➚" : "стрелка",
    "➛" : "стрелка",
    "➜" : "стрелка",
    "➝" : "стрелка",
    "➞" : "стрелка",
    "➟" : "стрелка",
    "➠" : "стрелка",
    "➡" : "стрелка",
    "➢" : "стрелка",
    "➣" : "стрелка",
    "➤" : "стрелка",
    "➥" : "стрелка",
    "➦" : "стрелка",
    "➧" : "стрелка",
    "➨" : "стрелка",
    "➩" : "стрелка",
    "➪" : "стрелка",
    "➫" : "стрелка",
    "➬" : "стрелка",
    "➭" : "стрелка",
    "➮" : "стрелка",
    "➯" : "стрелка",
    "➱" : "стрелка",
    "➲" : "стрелка",
    "➳" : "стрелка",
    "➴" : "стрелка",
    "➵" : "стрелка",
    "➶" : "стрелка",
    "➷" : "стрелка",
    "➸" : "стрелка",
    "➹" : "стрелка",
    "➺" : "стрелка",
    "➻" : "стрелка",
    "➼" : "стрелка",
    "➽" : "стрелка",
    "➾" : "стрелка",
    "⬀" : "стрелка",
    "⬁" : "стрелка",
    "⬂" : "стрелка",
    "⬃" : "стрелка",
    "⬄" : "стрелка",
    "⬅" : "стрелка",
    "⬆" : "стрелка",
    "⬇" : "стрелка",
    "⬈" : "стрелка",
    "⬉" : "стрелка",
    "⬊" : "стрелка",
    "⬋" : "стрелка",
    "⬌" : "стрелка",
    "⬍" : "стрелка",
    "⏎" : "стрелка",
    "▲" : "стрелка",
    "▼" : "стрелка",
    "◀" : "стрелка",
    "▶" : "стрелка",
    "⬎" : "стрелка",
    "⬏" : "стрелка",
    "⬐" : "стрелка",
    "⬑" : "стрелка",
    "☇" : "стрелка",
    "☈" : "стрелка",
    "⍃" : "стрелка",
    "⍄" : "стрелка",
    "⍇" : "стрелка",
    "⍈" : "стрелка",
    "⍐" : "стрелка",
    "⍗" : "стрелка",
    "⍌" : "стрелка",
    "⍓" : "стрелка",
    "⍍" : "стрелка",
    "⍔" : "стрелка",
    "⍏" : "стрелка",
    "⍖" : "стрелка",
    "⍅" : "стрелка",
    "⍆" : "стрелка",
    "♈" : "Знаки зодиака",
    "♉" : "Знаки зодиака",
    "♊" : "Знаки зодиака",
    "♋" : "Знаки зодиака",
    "♌" : "Знаки зодиака",
    "♍" : "Знаки зодиака",
    "♎" : "Знаки зодиака",
    "♏" : "Знаки зодиака",
    "♐" : "Знаки зодиака",
    "♑" : "Знаки зодиака",
    "♒" : "Знаки зодиака",
    "♓" : "Знаки зодиака",
    "✪" : "знак",
    "★" : "звезда",
    "☆" : "звезда",
    "✫" : "звезда",
    "✬" : "звезда",
    "✭" : "звезда",
    "✮" : "звезда",
    "✯" : "звезда",
    "✰" : "звезда",
    "⋆" : "звезда",
    "✧" : "звезда",
    "✩" : "звезда",
    "✵" : "звезда",
    "✦" : "звезда",
    "♔" : "шахматные фигуры",
    "♕" : "шахматные фигуры",
    "♖" : "шахматные фигуры",
    "♗" : "шахматные фигуры",
    "♘" : "шахматные фигуры",
    "♙" : "шахматные фигуры",
    "♚" : "шахматные фигуры",
    "♛" : "шахматные фигуры",
    "♜" : "шахматные фигуры",
    "♝" : "шахматные фигуры",
    "♞" : "шахматные фигуры",
    "♟" : "шахматные фигуры",
    "☺" : "смайлик",
    "㋛" : "смайлик",
    "ソ" : "смайлик",
    "ッ" : "смайлик",
    "ヅ" : "смайлик",
    "ツ" : "смайлик",
    "ゾ" : "смайлик",
    "シ" : "смайлик",
    "ジ" : "смайлик",
    "ｯ" : "смайлик",
    "ﾂ" : "смайлик",
    "ｼ" : "смайлик",
    "ﾝ" : "смайлик",
    "〴" : "смайлик",
    "ت" : "смайлик",
    "☻" : "смайлик",
    "☹" : "смайлик",
    "✽" : "звездочка",
    "✾" : "звездочка",
    "✿" : "звездочка",
    "✥" : "звездочка",
    "❀" : "звездочка",
    "❁" : "звездочка",
    "❃" : "звездочка",
    "❄" : "снежинка",
    "❅" : "снежинка",
    "❆" : "снежинка",
    "❇" : "звездочка",
    "❈" : "звездочка",
    "❉" : "звездочка",
    "❊" : "звездочка",
    "✢" : "звездочка",
    "✣" : "звездочка",
    "✤" : "звездочка",
    "❋" : "звездочка",
    "٭" : "звездочка",
    "✱" : "звездочка",
    "✲" : "звездочка",
    "✳" : "звездочка",
    "✴" : "звездочка",
    "✶" : "звездочка",
    "✷" : "звездочка",
    "✸" : "звездочка",
    "✹" : "звездочка",
    "✺" : "звездочка",
    "✻" : "звездочка",
    "✼" : "звездочка",
    "⁂" : "звездочка",
    "☩" : "крест",
    "☨" : "крест",
    "☦" : "крест",
    "✙" : "крест",
    "✚" : "крест",
    "✛" : "крест",
    "✜" : "крест",
    "✝" : "крест",
    "✞" : "крест",
    "✠" : "крест",
    "†" : "крест",
    "┿" : "крест",
    "☒" : "крест",
    "☓" : "крест",
    "✕" : "крест",
    "✖" : "крест",
    "✗" : "крест",
    "✘" : "крест",
    "✇" : "радиация",
    "☣" : "радиация",
    "♡" : "карточные масти",
    "♢" : "карточные масти",
    "♣" : "карточные масти",
    "♤" : "карточные масти",
    "♥" : "карточные масти",
    "♦" : "карточные масти",
    "♧" : "карточные масти",
    "✁" : "ножницы",
    "✂" : "ножницы",
    "✃" : "ножницы",
    "✄" : "ножницы",
    "♪" : "ноты",
    "♫" : "ноты",
    "♩" : "ноты",
    "♬" : "ноты",
    "♭" : "ноты",
    "♮" : "ноты",
    "♯" : "ноты",
    "°" : "градус",
    "™" : "трейдмарк",
    "©" : "копирайт",
    "®" : "зарегистрированная марка",
    "❏" : "квадрат",
    "❐" : "квадрат",
    "❑" : "квадрат",
    "❒" : "квадрат",
    "▀" : "квадрат",
    "▄" : "квадрат",
    "□" : "квадрат",
    "■" : "квадрат",
    "◙" : "квадрат",
    "▢" : "квадрат",
    "▣" : "квадрат",
    "◘" : "квадрат",
    "◧" : "квадрат",
    "◨" : "квадрат",
    "◩" : "квадрат",
    "◪" : "квадрат",
    "◫" : "квадрат",
    "▤" : "квадрат",
    "▥" : "квадрат",
    "▦" : "квадрат",
    "▧" : "квадрат",
    "▨" : "квадрат",
    "▩" : "квадрат",
    "▱" : "ромб",
    "▰" : "ромб",
    "▪" : "квадрат",
    "▫" : "квадрат",
    "▬" : "квадрат",
    "▭" : "квадрат",
    "▮" : "квадрат",
    "▯" : "квадрат",
    "◊" : "ромб",
    "◈" : "ромб",
    "☰" : "квадрат",
    "☲" : "квадрат",
    "☱" : "квадрат",
    "☴" : "квадрат",
    "☵" : "квадрат",
    "☶" : "квадрат",
    "☳" : "квадрат",
    "☷" : "квадрат",
    "░" : "квадрат",
    "▒" : "квадрат",
    "▓" : "квадрат",
    "▌" : "квадрат",
    "█" : "квадрат",
    "▉" : "квадрат",
    "▇" : "квадрат",
    "▆" : "квадрат",
    "▅" : "квадрат",
    "▄" : "квадрат",
    "▃" : "квадрат",
    "▂" : "квадрат"
   }
root = tk.Tk()
root.title("Поиск символов")
search_label = tk.Label(root, text="Введите название символа. Например: звездочка")
search_label.pack()
search_entry = tk.Entry(root)
search_entry.pack()
result_text = tk.Text(root, state="disabled")
result_text.pack(fill="both", expand=True)

def search_symbol():
    
    search_string = search_entry.get().lower()

   
    result_text.configure(state="normal")
    result_text.delete("1.0", tk.END)

    found = False 
    
    for symbol, name in symbol_dict.items():
        if search_string in name.lower():
            found = True 
            
            result_text.insert(tk.END, "{} : {}  \n".format(name, symbol))

    if not found: 
        result_text.insert(tk.END, "Символ не найден")

    result_text.configure(state="disabled")
        

    result_text.configure(state="disabled")
search_button = tk.Button(root, text="Найти символ", command=search_symbol)
search_button.pack(pady=5)
root.mainloop()
